# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/adarshsng/lending-club-loan-data-csv/loan.csv
# /kaggle/input/datasets/adarshsng/lending-club-loan-data-csv/LCDataDictionary.xlsx

# %% [markdown]
# # Capstone 2: Probability of Default (PD) Model
#
# ## Project Overview
# This project aims to build a predictive model to estimate the probability of loan default using LendingClub data.

# %% [markdown]
# ## 1. Data Loading and Initial Exploration
#
# We begin by loading the LendingClub dataset from Kaggle and performing an initial exploration of its structure.
#
# To ensure efficiency and avoid memory issues, a subset of 10,000 rows is first used for preliminary inspection. This allows us to review the dataset’s structure, examine column names, and identify potential data quality issues before working with the full dataset.
#
# After gaining an initial understanding, the full dataset is loaded to conduct a complete analysis. This step ensures that all observations are included for accurate modeling of loan default behavior.
#
# We also verify the dataset directory to confirm the presence of the main dataset file and accompanying data dictionary.

# %%
#Checking the dataset directory
os.listdir('/kaggle/input/datasets/adarshsng/lending-club-loan-data-csv')
# Out:
# ['loan.csv', 'LCDataDictionary.xlsx']

# %%
# Looking at the first 5 rows of the piece of our dataset
import pandas as pd

df = pd.read_csv(
    '/kaggle/input/datasets/adarshsng/lending-club-loan-data-csv/loan.csv',
    nrows = 10000,
    low_memory = False
)
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500             2500   36 months
# 1 NaN        NaN      30000        30000            30000   60 months
# 2 NaN        NaN       5000         5000             5000   36 months
# 3 NaN        NaN       4000         4000             4000   36 months
# 4 NaN        NaN      30000        30000            30000   60 months
#
#    int_rate  installment grade sub_grade       emp_title emp_length  \
# 0     13.56        84.92     C        C1            Chef  10+ years
# 1     18.94       777.23     D        D2     Postmaster   10+ years
# 2     17.97       180.69     D        D1  Administrative    6 years
# 3     18.94       146.51     D        D2   IT Supervisor  10+ years
# 4     16.14       731.78     C        C4        Mechanic  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0           RENT     55000.0        Not Verified  Dec-2018     Current
# 1       MORTGAGE     90000.0     Source Verified  Dec-2018     Current
# 2       MORTGAGE     59280.0     Source Verified  Dec-2018     Current
# 3       MORTGAGE     92000.0     Source Verified  Dec-2018     Current
# 4       MORTGAGE     57250.0        Not Verified  Dec-2018     Current
#
#   pymnt_plan  url  desc             purpose               title zip_code  \
# 0          n  NaN   NaN  debt_consolidation  Debt consolidation    109xx
# 1          n  NaN   NaN  debt_consolidation  Debt consolidation    713xx
# 2          n  NaN   NaN  debt_consolidation  Debt consolidation    490xx
# 3          n  NaN   NaN  debt_consolidation  Debt consolidation    985xx
# 4          n  NaN   NaN  debt_consolidation  Debt consolidation    212xx
#
#   addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0         NY  18.24            0         Apr-2001               1
# 1         LA  26.52            0         Jun-1987               0
# 2         MI  10.51            0         Apr-2011               0
# 3         WA  16.74            0         Feb-2006               0
# 4         MD  26.35            0         Dec-2000               0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                     NaN                    45.0         9        1
# 1                    71.0                    75.0        13        1
# 2                     NaN                     NaN         8        0
# 3                     NaN                     NaN        10        0
# 4                     NaN                     NaN        12        0
#
#    revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 0       4341        10.3         34                   w    2386.02
# 1      12315        24.2         44                   w   29387.75
# 2       4599        19.1         13                   w    4787.21
# 3       5468        78.1         13                   w    3831.93
# 4        829         3.6         26                   w   29339.02
#
#    out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        2386.02       167.02           167.02           113.98
# 1       29387.75      1507.11          1507.11           612.25
# 2        4787.21       353.89           353.89           212.79
# 3        3831.93       286.71           286.71           168.07
# 4       29339.02      1423.21          1423.21           660.98
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          53.04                 0.0         0.0                      0.0
# 1         894.86                 0.0         0.0                      0.0
# 2         141.10                 0.0         0.0                      0.0
# 3         118.64                 0.0         0.0                      0.0
# 4         762.23                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Feb-2019            84.92     Mar-2019           Feb-2019
# 1     Feb-2019           777.23     Mar-2019           Feb-2019
# 2     Feb-2019           180.69     Mar-2019           Feb-2019
# 3     Feb-2019           146.51     Mar-2019           Feb-2019
# 4     Feb-2019           731.78     Mar-2019           Feb-2019
#
#    collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 0                           0                          NaN            1
# 1                           0                          NaN            1
# 2                           0                          NaN            1
# 3                           0                          NaN            1
# 4                           0                          NaN            1
#
#   application_type  annual_inc_joint  dti_joint verification_status_joint  \
# 0       Individual               NaN        NaN                       NaN
# 1       Individual               NaN        NaN                       NaN
# 2       Individual               NaN        NaN                       NaN
# 3       Individual               NaN        NaN                       NaN
# 4       Individual               NaN        NaN                       NaN
#
#    acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 0               0             0        16901            2            2
# 1               0          1208       321915            4            4
# 2               0             0       110299            0            1
# 3               0           686       305049            1            5
# 4               0             0       116007            3            5
#
#    open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 0            1            2                 2.0         12560     69.0
# 1            2            3                 3.0         87153     88.0
# 2            0            2                14.0          7150     72.0
# 3            3            5                 5.0         30683     68.0
# 4            3            5                 4.0         28845     89.0
#
#    open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0            2            7        2137      28.0             42000       1
# 1            4            5         998      57.0             50800       2
# 2            0            2           0      35.0             24100       1
# 3            0            0        3761      70.0              7000       2
# 4            2            4         516      54.0             23100       1
#
#    total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0           11             2                     9       1878.0
# 1           15             2                    10      24763.0
# 2            5             0                     4      18383.0
# 3            4             3                     5      30505.0
# 4            0             0                     9       9667.0
#
#    bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0         34360.0      5.9                         0            0
# 1         13761.0      8.3                         0            0
# 2         13800.0      0.0                         0            0
# 3          1239.0     75.2                         0            0
# 4          8471.0      8.9                         0            0
#
#    mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0               140.0                   212                      1
# 1               163.0                   378                      4
# 2                87.0                    92                     15
# 3                62.0                   154                     64
# 4                53.0                   216                      2
#
#    mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 0               1         0                   1.0                       NaN
# 1               3         3                   4.0                       NaN
# 2              14         2                  77.0                       NaN
# 3               5         3                  64.0                       NaN
# 4               2         2                   2.0                       NaN
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    2.0                             NaN
# 1                    4.0                             NaN
# 2                   14.0                             NaN
# 3                    5.0                             NaN
# 4                   13.0                             NaN
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                      0               2                5            3
# 1                      0               2                4            4
# 2                      0               0                3            3
# 3                      0               1                2            1
# 4                      0               2                2            3
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0          3         16              7             18                    5
# 1          9         27              8             14                    4
# 2          3          4              6              7                    3
# 3          2          7              2              3                    2
# 4          8          9              6             15                    2
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0         9               0.0             0                   0
# 1        13               0.0             0                   0
# 2         8               0.0             0                   0
# 3        10               0.0             0                   0
# 4        12               0.0             0                   0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                   3           100.0               0.0                     1
# 1                   6            95.0               0.0                     1
# 2                   0           100.0               0.0                     0
# 3                   3           100.0             100.0                     0
# 4                   5            92.3               0.0                     0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0          0            60124              16901           36500
# 1          0           372872              99468           15000
# 2          0           136927              11749           13800
# 3          0           385183              36151            5000
# 4          0           157548              29674            9300
#
#    total_il_high_credit_limit  revol_bal_joint sec_app_earliest_cr_line  \
# 0                       18124              NaN                      NaN
# 1                       94072              NaN                      NaN
# 2                       10000              NaN                      NaN
# 3                       44984              NaN                      NaN
# 4                       32332              NaN                      NaN
#
#    sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 NaN                  NaN                    NaN
# 1                 NaN                  NaN                    NaN
# 2                 NaN                  NaN                    NaN
# 3                 NaN                  NaN                    NaN
# 4                 NaN                  NaN                    NaN
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog hardship_flag  hardship_type  \
# 0                                  NaN             N            NaN
# 1                                  NaN             N            NaN
# 2                                  NaN             N            NaN
# 3                                  NaN             N            NaN
# 4                                  NaN             N            NaN
#
#    hardship_reason  hardship_status  deferral_term  hardship_amount  \
# 0              NaN              NaN            NaN              NaN
# 1              NaN              NaN            NaN              NaN
# 2              NaN              NaN            NaN              NaN
# 3              NaN              NaN            NaN              NaN
# 4              NaN              NaN            NaN              NaN
#
#    hardship_start_date  hardship_end_date  payment_plan_start_date  \
# 0                  NaN                NaN                      NaN
# 1                  NaN                NaN                      NaN
# 2                  NaN                NaN                      NaN
# 3                  NaN                NaN                      NaN
# 4                  NaN                NaN                      NaN
#
#    hardship_length  hardship_dpd  hardship_loan_status  \
# 0              NaN           NaN                   NaN
# 1              NaN           NaN                   NaN
# 2              NaN           NaN                   NaN
# 3              NaN           NaN                   NaN
# 4              NaN           NaN                   NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#    debt_settlement_flag_date  settlement_status  settlement_date  \
# 0                        NaN                NaN              NaN
# 1                        NaN                NaN              NaN
# 2                        NaN                NaN              NaN
# 3                        NaN                NaN              NaN
# 4                        NaN                NaN              NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
# Checking the shape, which tells us that it contains 145 columns
df.shape
# Out:
# (10000, 145)

# %%
#Checking all the columns
pd.set_option('display.max_columns', None)
list(df.columns)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_act_il',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'revol_bal_joint',
#  'sec_app_earliest_cr_line',
#  'sec_app_inq_last_6mths',
#  'sec_app_mort_acc',
#  'sec_app_open_acc',
#  'sec_app_revol_util',
#  'sec_app_open_act_il',
#  'sec_app_num_rev_accts',
#  'sec_app_chargeoff_within_12_mths',
#  'sec_app_collections_12_mths_ex_med',
#  'sec_app_mths_since_last_major_derog',
#  'hardship_flag',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'deferral_term',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'payment_plan_start_date',
#  'hardship_length',
#  'hardship_dpd',
#  'hardship_loan_status',
#  'orig_projected_additional_accrued_interest',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount',
#  'disbursement_method',
#  'debt_settlement_flag',
#  'debt_settlement_flag_date',
#  'settlement_status',
#  'settlement_date',
#  'settlement_amount',
#  'settlement_percentage',
#  'settlement_term']

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Current               9800
# Fully Paid             177
# In Grace Period         11
# Late (31-120 days)      10
# Charged Off              1
# Late (16-30 days)        1
# Name: count, dtype: int64

# %% [markdown]
# This piece of dataset (10,000 rows) is heavily imbalanced with only 1 "Charged Off" loan. "Current" loans cannot be used for PD model, because we don't know if they will default yet. We are going to examine full dataset next and
# create a binary model.

# %%
# Loading a full dataset
import pandas as pd

df = pd.read_csv(
    '/kaggle/input/datasets/adarshsng/lending-club-loan-data-csv/loan.csv',
    low_memory = False
)
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
# 1 NaN        NaN      30000        30000          30000.0   60 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN       4000         4000           4000.0   36 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#    int_rate  installment grade sub_grade       emp_title emp_length  \
# 0     13.56        84.92     C        C1            Chef  10+ years
# 1     18.94       777.23     D        D2     Postmaster   10+ years
# 2     17.97       180.69     D        D1  Administrative    6 years
# 3     18.94       146.51     D        D2   IT Supervisor  10+ years
# 4     16.14       731.78     C        C4        Mechanic  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0           RENT     55000.0        Not Verified  Dec-2018     Current
# 1       MORTGAGE     90000.0     Source Verified  Dec-2018     Current
# 2       MORTGAGE     59280.0     Source Verified  Dec-2018     Current
# 3       MORTGAGE     92000.0     Source Verified  Dec-2018     Current
# 4       MORTGAGE     57250.0        Not Verified  Dec-2018     Current
#
#   pymnt_plan  url desc             purpose               title zip_code  \
# 0          n  NaN  NaN  debt_consolidation  Debt consolidation    109xx
# 1          n  NaN  NaN  debt_consolidation  Debt consolidation    713xx
# 2          n  NaN  NaN  debt_consolidation  Debt consolidation    490xx
# 3          n  NaN  NaN  debt_consolidation  Debt consolidation    985xx
# 4          n  NaN  NaN  debt_consolidation  Debt consolidation    212xx
#
#   addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0         NY  18.24          0.0         Apr-2001             1.0
# 1         LA  26.52          0.0         Jun-1987             0.0
# 2         MI  10.51          0.0         Apr-2011             0.0
# 3         WA  16.74          0.0         Feb-2006             0.0
# 4         MD  26.35          0.0         Dec-2000             0.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                     NaN                    45.0       9.0      1.0
# 1                    71.0                    75.0      13.0      1.0
# 2                     NaN                     NaN       8.0      0.0
# 3                     NaN                     NaN      10.0      0.0
# 4                     NaN                     NaN      12.0      0.0
#
#    revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 0       4341        10.3       34.0                   w    2386.02
# 1      12315        24.2       44.0                   w   29387.75
# 2       4599        19.1       13.0                   w    4787.21
# 3       5468        78.1       13.0                   w    3831.93
# 4        829         3.6       26.0                   w   29339.02
#
#    out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        2386.02       167.02           167.02           113.98
# 1       29387.75      1507.11          1507.11           612.25
# 2        4787.21       353.89           353.89           212.79
# 3        3831.93       286.71           286.71           168.07
# 4       29339.02      1423.21          1423.21           660.98
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          53.04                 0.0         0.0                      0.0
# 1         894.86                 0.0         0.0                      0.0
# 2         141.10                 0.0         0.0                      0.0
# 3         118.64                 0.0         0.0                      0.0
# 4         762.23                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Feb-2019            84.92     Mar-2019           Feb-2019
# 1     Feb-2019           777.23     Mar-2019           Feb-2019
# 2     Feb-2019           180.69     Mar-2019           Feb-2019
# 3     Feb-2019           146.51     Mar-2019           Feb-2019
# 4     Feb-2019           731.78     Mar-2019           Feb-2019
#
#    collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 0                         0.0                          NaN            1
# 1                         0.0                          NaN            1
# 2                         0.0                          NaN            1
# 3                         0.0                          NaN            1
# 4                         0.0                          NaN            1
#
#   application_type  annual_inc_joint  dti_joint verification_status_joint  \
# 0       Individual               NaN        NaN                       NaN
# 1       Individual               NaN        NaN                       NaN
# 2       Individual               NaN        NaN                       NaN
# 3       Individual               NaN        NaN                       NaN
# 4       Individual               NaN        NaN                       NaN
#
#    acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 0             0.0           0.0      16901.0          2.0          2.0
# 1             0.0        1208.0     321915.0          4.0          4.0
# 2             0.0           0.0     110299.0          0.0          1.0
# 3             0.0         686.0     305049.0          1.0          5.0
# 4             0.0           0.0     116007.0          3.0          5.0
#
#    open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 0          1.0          2.0                 2.0       12560.0     69.0
# 1          2.0          3.0                 3.0       87153.0     88.0
# 2          0.0          2.0                14.0        7150.0     72.0
# 3          3.0          5.0                 5.0       30683.0     68.0
# 4          3.0          5.0                 4.0       28845.0     89.0
#
#    open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0          2.0          7.0      2137.0      28.0           42000.0     1.0
# 1          4.0          5.0       998.0      57.0           50800.0     2.0
# 2          0.0          2.0         0.0      35.0           24100.0     1.0
# 3          0.0          0.0      3761.0      70.0            7000.0     2.0
# 4          2.0          4.0       516.0      54.0           23100.0     1.0
#
#    total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0         11.0           2.0                   9.0       1878.0
# 1         15.0           2.0                  10.0      24763.0
# 2          5.0           0.0                   4.0      18383.0
# 3          4.0           3.0                   5.0      30505.0
# 4          0.0           0.0                   9.0       9667.0
#
#    bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0         34360.0      5.9                       0.0          0.0
# 1         13761.0      8.3                       0.0          0.0
# 2         13800.0      0.0                       0.0          0.0
# 3          1239.0     75.2                       0.0          0.0
# 4          8471.0      8.9                       0.0          0.0
#
#    mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0               140.0                 212.0                    1.0
# 1               163.0                 378.0                    4.0
# 2                87.0                  92.0                   15.0
# 3                62.0                 154.0                   64.0
# 4                53.0                 216.0                    2.0
#
#    mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 0             1.0       0.0                   1.0                       NaN
# 1             3.0       3.0                   4.0                       NaN
# 2            14.0       2.0                  77.0                       NaN
# 3             5.0       3.0                  64.0                       NaN
# 4             2.0       2.0                   2.0                       NaN
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    2.0                             NaN
# 1                    4.0                             NaN
# 2                   14.0                             NaN
# 3                    5.0                             NaN
# 4                   13.0                             NaN
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                    0.0             2.0              5.0          3.0
# 1                    0.0             2.0              4.0          4.0
# 2                    0.0             0.0              3.0          3.0
# 3                    0.0             1.0              2.0          1.0
# 4                    0.0             2.0              2.0          3.0
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0        3.0       16.0            7.0           18.0                  5.0
# 1        9.0       27.0            8.0           14.0                  4.0
# 2        3.0        4.0            6.0            7.0                  3.0
# 3        2.0        7.0            2.0            3.0                  2.0
# 4        8.0        9.0            6.0           15.0                  2.0
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0       9.0               0.0           0.0                 0.0
# 1      13.0               0.0           0.0                 0.0
# 2       8.0               0.0           0.0                 0.0
# 3      10.0               0.0           0.0                 0.0
# 4      12.0               0.0           0.0                 0.0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                 3.0           100.0               0.0                   1.0
# 1                 6.0            95.0               0.0                   1.0
# 2                 0.0           100.0               0.0                   0.0
# 3                 3.0           100.0             100.0                   0.0
# 4                 5.0            92.3               0.0                   0.0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0        0.0          60124.0            16901.0         36500.0
# 1        0.0         372872.0            99468.0         15000.0
# 2        0.0         136927.0            11749.0         13800.0
# 3        0.0         385183.0            36151.0          5000.0
# 4        0.0         157548.0            29674.0          9300.0
#
#    total_il_high_credit_limit  revol_bal_joint sec_app_earliest_cr_line  \
# 0                     18124.0              NaN                      NaN
# 1                     94072.0              NaN                      NaN
# 2                     10000.0              NaN                      NaN
# 3                     44984.0              NaN                      NaN
# 4                     32332.0              NaN                      NaN
#
#    sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 NaN                  NaN                    NaN
# 1                 NaN                  NaN                    NaN
# 2                 NaN                  NaN                    NaN
# 3                 NaN                  NaN                    NaN
# 4                 NaN                  NaN                    NaN
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N           NaN
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                  NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
df.shape
# Out:
# (2260668, 145)

# %% [markdown]
# In our full dataset we have 2.26 million rows and 145 columns.

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid                                             1041952
# Current                                                 919695
# Charged Off                                             261655
# Late (31-120 days)                                       21897
# In Grace Period                                           8952
# Late (16-30 days)                                         3737
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     31
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Target Variable Definition and Distribution
#
# The `loan_status` variable represents the current or final repayment state of each loan and serves as the foundation for defining the target variable in this analysis. Since the objective is to model the probability of default (PD), only loans with known and reliable outcomes were considered. Loans labeled as **“Current”** were excluded because their final repayment status has not yet been determined, and including them would introduce uncertainty and potential misclassification into the model. Similarly, intermediate statuses such as **“In Grace Period”** and early-stage delinquency (e.g., **“Late (16–30 days)”**) were removed, as these loans may still recover and do not necessarily represent true default events.
#
# To construct a binary target variable, loans were categorized into two groups based on their repayment outcomes. Loans labeled as **“Fully Paid”** were classified as non-default (0), indicating successful repayment. Loans labeled as **“Charged Off”**, **“Default”**, and **“Late (31–120 days)”** were classified as default (1), as these represent severe delinquency or failure to meet repayment obligations. A new variable, default, was created to capture this classification, where 0 indicates a non-defaulted loan and 1 indicates a defaulted or high-risk loan. This transformation ensures a clear and consistent definition of default, which is essential for building a reliable predictive model.
# The following steps implement this classification by filtering relevant loan statuses and creating a binary target variable.

# %%
# Defining categories

bad_status = [
    'Charged Off', 
    'Default', 
    'Late (31-120 days)'
]

good_status = ['Fully Paid']

# %%
# Filter dataset

df = df[df['loan_status'].isin(bad_status + good_status)].copy()

# %%
# Creating a binary target

df['default'] = df['loan_status'].apply(lambda x:1 if x in bad_status else 0)

# %%
# Check the result
df['default'].value_counts()
# Out:
# default
# 0    1041952
# 1     283583
# Name: count, dtype: int64

# %% [markdown]
# After defining the binary target variable `default`, the distribution of loan outcomes was examined using the *value_counts()* method, which counts the number of occurrences of each unique value in the column. The results show that the majority of loans are classified as non-default (0), with 1,041,952 observations, while 283,583 loans are classified as default (1).
#
# This indicates that the dataset is moderately imbalanced, with approximately 79% non-default cases and 21% default cases. Such an imbalance is typical in credit risk datasets, as most borrowers successfully meet their repayment obligations, while a smaller proportion experience financial distress.
#
# This class imbalance is an important consideration for modeling, as predictive algorithms must be able to accurately identify the minority class (default cases) despite their lower frequency.

# %% [markdown]
# ## 3. Data Cleaning and Preprocessing
#
# This section focuses on preparing the dataset for modeling by removing data leakage, handling missing values, and refining the dataset structure. These steps ensure that the model is trained on reliable and meaningful features that reflect real-world prediction scenarios.

# %% [markdown]
# **Removal of Data Leakage Features**
#
#
# Certain variables were removed from the dataset due to potential data leakage, as they contain information that becomes available only after the loan has been issued or after repayment behavior has already occurred. Including such variables would result in unrealistic model performance, since they effectively reveal the outcome of the loan.
#
# Examples of these variables include total payment amounts, recovery-related metrics, and last payment information, all of which are directly influenced by whether a borrower ultimately defaults. To ensure that the model reflects a real-world prediction scenario at the time of loan origination, these columns were excluded from the analysis.
#
# The following variables were identified as containing post-outcome or repayment-related information and were therefore removed: total payment variables (total_pymnt, total_pymnt_inv), recovery-related variables (recoveries, collection_recovery_fee), repayment components (total_rec_prncp, total_rec_int, total_rec_late_fee), and variables reflecting repayment timing and remaining balance (last_pymnt_d, last_pymnt_amnt, out_prncp, out_prncp_inv).

# %%
# Creating leakage list:

leakage_cols = [
    'total_pymnt',
    'total_pymnt_inv',
    'total_rec_prncp',
    'total_rec_int',
    'total_rec_late_fee',
    'recoveries',
    'collection_recovery_fee',
    'last_pymnt_d',
    'last_pymnt_amnt',
    'out_prncp',
    'out_prncp_inv'
]

# %%
# Dropping the leakage columns from our dataset:

df = df.drop(columns = leakage_cols, errors = 'ignore')

# %%
# Checking the new shape of the dataset:
df.shape
# Out:
# (1325535, 135)

# %%
# Checking if all of the leakage columns got dropped
[col for col in leakage_cols if col in df.columns]
# Out:
# []

# %% [markdown]
# After filtering the dataset and removing leakage variables, the number of columns decreased from 145 to 135. Although 11 leakage columns were removed, one new binary target column, default, was added, resulting in a net reduction of 10 columns.

# %% [markdown]
# **Removal of Target Variable Source**
#
# After constructing the binary target variable `default`, the original `loan_status` column has to be removed from the dataset. This is because `loan_status` directly reflects the final outcome of each loan and was used to derive the target variable. Keeping this column in the dataset would introduce target leakage, allowing the model to trivially infer the outcome and resulting in misleading performance. Therefore, it was excluded to ensure that the model relies only on independent features available at the time of loan origination.

# %%
# Dropping 
df = df.drop(columns=['loan_status'], errors='ignore')

# %%
print("Shape after dropping loan_status:", df.shape)
# Out:
# Shape after dropping loan_status: (1325535, 134)

# %% [markdown]
# **Handling Missing Values**
#
# To understand the quality of the dataset, I need to examine missing values across all columns. I am going to use the *isnull().sum()* function to count how many missing values are present in each variable and sort the results to identify the columns with the most missing data. I will after calculate the percentage of missing values relative to the total number of rows. These results will be combined into a new DataFrame (`missing_df`) to clearly summarize and analyze the extent of missing data in the dataset.

# %%
# Counting how many missing values are in each variable with isnull().sum()
missing = df.isnull().sum().sort_values(ascending=False)
missing_percent = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    'missing_count': missing,
    'missing_percent': missing_percent
})

missing_df.head(20)
# Out:
#                                             missing_count  missing_percent
# id                                                1325535       100.000000
# member_id                                         1325535       100.000000
# url                                               1325535       100.000000
# orig_projected_additional_accrued_interest        1320632        99.630112
# sec_app_mths_since_last_major_derog               1318750        99.488131
# hardship_length                                   1318537        99.472062
# payment_plan_start_date                           1318537        99.472062
# hardship_dpd                                      1318537        99.472062
# hardship_payoff_balance_amount                    1318537        99.472062
# hardship_loan_status                              1318537        99.472062
# deferral_term                                     1318537        99.472062
# hardship_status                                   1318537        99.472062
# hardship_amount                                   1318537        99.472062
# hardship_last_payment_amount                      1318537        99.472062
# hardship_type                                     1318537        99.472062
# hardship_start_date                               1318537        99.472062
# hardship_reason                                   1318537        99.472062
# hardship_end_date                                 1318537        99.472062
# sec_app_revol_util                                1307363        98.629082
# revol_bal_joint                                   1307027        98.603734

# %%
# Dropping high - missing columns (>70%)
cols_to_drop = missing_df[missing_df['missing_percent']>70].index
df = df.drop(columns = cols_to_drop)

# %% [markdown]
# The missing values analysis revealed that several variables contain an extremely high proportion of missing data, in many cases exceeding 99%. These columns primarily correspond to conditional features, such as hardship-related variables and secondary applicant information, which are only populated for a small subset of observations.
#
# Because these variables are largely incomplete and provide limited information for the majority of loans, they were removed from the dataset. Retaining such columns would introduce noise and reduce the effectiveness of the predictive model.

# %%
# Checking the shape again:
df.shape
# Out:
# (1325535, 92)

# %%
# Check the remaining missing values:
df.isnull().sum().sort_values(ascending = False).head(10)
# Out:
# mths_since_recent_revol_delinq    881766
# il_util                           875663
# mths_since_rcnt_il                819596
# all_util                          805909
# total_cu_tl                       805855
# open_acc_6m                       805855
# inq_last_12m                      805855
# open_il_12m                       805854
# max_bal_bc                        805854
# open_rv_24m                       805854
# dtype: int64

# %% [markdown]
# After removing variables with extremely high levels of missing data, several features still exhibit moderate levels of missingness. These variables are primarily related to borrower behavior and credit history, such as recent delinquencies, credit inquiries, and account activity.
#
# In many cases, missing values in these columns are not random but instead indicate the absence of a specific event (e.g., no recent delinquency or no credit inquiries). Therefore, these variables will be retained and their missing values will be handled through imputation to preserve potentially useful information for modeling.

# %% [markdown]
# ## 4. Feature Engineering and Data Preparation
#
# This section focuses on preparing the dataset for predictive modeling by refining feature selection, handling missing values, and transforming variables into formats suitable for machine learning algorithms. The goal is to ensure that all features are informative, non-redundant, and reflect information available at the time of loan origination, while minimizing noise and potential bias.

# %%
# Structure overview of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1325535 entries, 100 to 2260664
# Data columns (total 92 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   loan_amnt                       1325535 non-null  int64
#  1   funded_amnt                     1325535 non-null  int64
#  2   funded_amnt_inv                 1325535 non-null  float64
#  3   term                            1325535 non-null  object
#  4   int_rate                        1325535 non-null  float64
#  5   installment                     1325535 non-null  float64
#  6   grade                           1325535 non-null  object
#  7   sub_grade                       1325535 non-null  object
#  8   emp_title                       1240897 non-null  object
#  9   emp_length                      1248144 non-null  object
#  10  home_ownership                  1325535 non-null  object
#  11  annual_inc                      1325535 non-null  float64
#  12  verification_status             1325535 non-null  object
#  13  issue_d                         1325535 non-null  object
#  14  pymnt_plan                      1325535 non-null  object
#  15  purpose                         1325535 non-null  object
#  16  title                           1309780 non-null  object
#  17  zip_code                        1325534 non-null  object
#  18  addr_state                      1325535 non-null  object
#  19  dti                             1325195 non-null  float64
#  20  delinq_2yrs                     1325535 non-null  float64
#  21  earliest_cr_line                1325535 non-null  object
#  22  inq_last_6mths                  1325534 non-null  float64
#  23  mths_since_last_delinq          657494 non-null   float64
#  24  open_acc                        1325535 non-null  float64
#  25  pub_rec                         1325535 non-null  float64
#  26  revol_bal                       1325535 non-null  int64
#  27  revol_util                      1324694 non-null  float64
#  28  total_acc                       1325535 non-null  float64
#  29  initial_list_status             1325535 non-null  object
#  30  last_credit_pull_d              1325480 non-null  object
#  31  collections_12_mths_ex_med      1325479 non-null  float64
#  32  policy_code                     1325535 non-null  int64
#  33  application_type                1325535 non-null  object
#  34  acc_now_delinq                  1325535 non-null  float64
#  35  tot_coll_amt                    1258008 non-null  float64
#  36  tot_cur_bal                     1258008 non-null  float64
#  37  open_acc_6m                     519680 non-null   float64
#  38  open_act_il                     519681 non-null   float64
#  39  open_il_12m                     519681 non-null   float64
#  40  open_il_24m                     519681 non-null   float64
#  41  mths_since_rcnt_il              505939 non-null   float64
#  42  total_bal_il                    519681 non-null   float64
#  43  il_util                         449872 non-null   float64
#  44  open_rv_12m                     519681 non-null   float64
#  45  open_rv_24m                     519681 non-null   float64
#  46  max_bal_bc                      519681 non-null   float64
#  47  all_util                        519626 non-null   float64
#  48  total_rev_hi_lim                1258008 non-null  float64
#  49  inq_fi                          519681 non-null   float64
#  50  total_cu_tl                     519680 non-null   float64
#  51  inq_last_12m                    519680 non-null   float64
#  52  acc_open_past_24mths            1278254 non-null  float64
#  53  avg_cur_bal                     1257985 non-null  float64
#  54  bc_open_to_buy                  1264563 non-null  float64
#  55  bc_util                         1263802 non-null  float64
#  56  chargeoff_within_12_mths        1325479 non-null  float64
#  57  delinq_amnt                     1325535 non-null  float64
#  58  mo_sin_old_il_acct              1220457 non-null  float64
#  59  mo_sin_old_rev_tl_op            1258007 non-null  float64
#  60  mo_sin_rcnt_rev_tl_op           1258007 non-null  float64
#  61  mo_sin_rcnt_tl                  1258008 non-null  float64
#  62  mort_acc                        1278254 non-null  float64
#  63  mths_since_recent_bc            1265477 non-null  float64
#  64  mths_since_recent_inq           1154171 non-null  float64
#  65  mths_since_recent_revol_delinq  443769 non-null   float64
#  66  num_accts_ever_120_pd           1258008 non-null  float64
#  67  num_actv_bc_tl                  1258008 non-null  float64
#  68  num_actv_rev_tl                 1258008 non-null  float64
#  69  num_bc_sats                     1269694 non-null  float64
#  70  num_bc_tl                       1258008 non-null  float64
#  71  num_il_tl                       1258008 non-null  float64
#  72  num_op_rev_tl                   1258008 non-null  float64
#  73  num_rev_accts                   1258007 non-null  float64
#  74  num_rev_tl_bal_gt_0             1258008 non-null  float64
#  75  num_sats                        1269694 non-null  float64
#  76  num_tl_120dpd_2m                1208561 non-null  float64
#  77  num_tl_30dpd                    1258008 non-null  float64
#  78  num_tl_90g_dpd_24m              1258008 non-null  float64
#  79  num_tl_op_past_12m              1258008 non-null  float64
#  80  pct_tl_nvr_dlq                  1257854 non-null  float64
#  81  percent_bc_gt_75                1264152 non-null  float64
#  82  pub_rec_bankruptcies            1324838 non-null  float64
#  83  tax_liens                       1325496 non-null  float64
#  84  tot_hi_cred_lim                 1258008 non-null  float64
#  85  total_bal_ex_mort               1278254 non-null  float64
#  86  total_bc_limit                  1278254 non-null  float64
#  87  total_il_high_credit_limit      1258008 non-null  float64
#  88  hardship_flag                   1325535 non-null  object
#  89  disbursement_method             1325535 non-null  object
#  90  debt_settlement_flag            1325535 non-null  object
#  91  default                         1325535 non-null  int64
# dtypes: float64(67), int64(5), object(20)
# memory usage: 940.5+ MB

# %% [markdown]
# ## 4.1 Data Type and Structure Analysis
#
# After using the .info() method, the dataset structure showed a total of 92 columns that consist of both numerical and categorical variables. Numerical variables (e.g., loan amount, interest rate, and debt-to-income ratio) are stored as integer and float types, while categorical variables (stored as object type) include features such as loan grade, employment information, and home ownership status.
#
# However, not all object-type variables are purely categorical, as some represent dates or require additional cleaning and transformation (e.g., term and employment length). Additionally, several variables exhibit missing values, particularly those related to borrower-specific conditions (such as employment details or hardship-related variables), which are not applicable to all observations. This highlights the need for further preprocessing, including handling missing values, transforming categorical variables, and removing irrelevant or high-cardinality features.

# %% [markdown]
# ## 4.2 Feature Selection and Variable Description
#
# At this stage, the dataset is further refined by selecting features that are expected to be highly relevant for predicting credit default risk and organizing them into meaningful categories. **Loan structure variables** such as *loan_amnt*, *funded_amnt*, *funded_amnt_inv*, *term*, *int_rate*, and *installment*capture the size, duration, and cost of the loan. **Credit quality** is represented through LendingClub’s internal risk assessments (*grade and sub_grade*), which summarize borrower risk profiles. Borrower financial characteristics, including *annual_inc* and *dti *(debt-to-income ratio), provide insight into the applicant’s financial capacity to service debt.
#
# **Credit history variables** such as *delinq_2yrs*, *earliest_cr_line*, *inq_last_6mths*, *open_acc*, and *total_acc* reflect the borrower’s past credit behavior and exposure to debt. **Measures of credit utilization**, including *revol_bal* and *revol_util*, indicate how heavily the borrower relies on available credit, which is a key indicator of financial stress. Additional **behavioral and account-level variables**, such as *acc_now_delinq*, *tot_cur_bal*, *total_rev_hi_lim*, *avg_cur_bal*, *bc_util*, and *percent_bc_gt_75*, are included to provide deeper insight into repayment patterns and credit usage dynamics.
#
# The target variable default is retained as the response variable, representing whether a loan results in default (1) or non-default (0).
#
# At the same time, several features will be removed due to lack of predictive value, redundancy, excessive sparsity, or potential data leakage. These include identifiers and noisy text fields (e.g.,*zip_code, title, emp_title*), near-constant variables (e.g., *pymnt_plan, policy_code*), and variables containing post-outcome information (e.g., *debt_settlement_flag*), which could introduce bias into the model. Removing these features ensures that the model is trained only on information that would realistically be available at the time of loan origination.

# %%
# Dropping columns with low predictive value, high noise, or potential data leakage

drop_cols = [
    'zip_code',
    'title',
    'emp_title',
    'pymnt_plan',
    'policy_code',
    'debt_settlement_flag'
]

df = df.drop(columns=drop_cols)

# %%
# Drop last_credit_pull_d as it contains information from after loan origination, 
# which would introduce data leakage into the model:

df = df.drop(columns=['last_credit_pull_d'])

# %%
# Checking the shape
print(f'Remaining columns: {df.shape[1]}')
# Out:
# Remaining columns: 85

# %% [markdown]
# ## 4.3 Missing Values Analysis and Handling

# %%
# Columns with no missing values:
no_missing_cols = df.columns[df.isnull().sum() == 0]

# Columns with missing values:
missing_cols = df.columns[df.isnull().sum() > 0]

# %%
# Checking the amount of each:
len(no_missing_cols)
# Out:
# 27

# %%
len(missing_cols)
# Out:
# 58

# %%
# Split missing columns by type:
missing_num_cols = df[missing_cols].select_dtypes(include=['int64', 'float64']).columns
missing_cat_cols = df[missing_cols].select_dtypes(include=['object']).columns

# %%
# Printing columns with missing values separately numerical from categorical
print("Numerical columns with missing values:")
print(list(missing_num_cols))

print("\nCategorical columns with missing values:")
print(list(missing_cat_cols))
# Out:
# Numerical columns with missing values:
# ['dti', 'inq_last_6mths', 'mths_since_last_delinq', 'revol_util', 'collections_12_mths_ex_med', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit']
#
# Categorical columns with missing values:
# ['emp_length']

# %%
# Starting with categorical column 'emp_length':
df['emp_length'].head(20)
# Out:
# 100      5 years
# 152     < 1 year
# 170    10+ years
# 186    10+ years
# 215      3 years
# 269      4 years
# 271    10+ years
# 296      5 years
# 369      5 years
# 379      4 years
# 402      3 years
# 412    10+ years
# 445    10+ years
# 510      5 years
# 576    10+ years
# 646    10+ years
# 765      4 years
# 800       1 year
# 829     < 1 year
# 835       1 year
# Name: emp_length, dtype: object

# %%
df['emp_length'].isnull().sum()
# Out:
# np.int64(77391)

# %% [markdown]
# Approximately 5.8% of observations (77,391 out of 1,325,535) have missing values in the employment length variable. Since this proportion is relatively small and employment history is an important indicator of borrower stability, the variable is going to be retained. The categorical values will be converted into numeric form, and a separate binary indicator is going to be created to capture missing employment information, allowing the model to learn whether missingness itself is predictive of default risk.

# %%
# Inspecting unique values first:

sorted(df['emp_length'].dropna().unique())
# Out:
# ['1 year',
#  '10+ years',
#  '2 years',
#  '3 years',
#  '4 years',
#  '5 years',
#  '6 years',
#  '7 years',
#  '8 years',
#  '9 years',
#  '< 1 year']

# %%
# Step 1: Converting special cases to string numbers (not integers!)
df['emp_length'] = df['emp_length'].replace({
    '< 1 year': '1',
    '10+ years': '10'
})

# Step 2: Removing text
df['emp_length'] = df['emp_length'].str.replace(' years', '', regex=False)
df['emp_length'] = df['emp_length'].str.replace(' year', '', regex=False)
df['emp_length'] = df['emp_length'].str.strip()

# Step 3: Converting to numeric
df['emp_length'] = pd.to_numeric(df['emp_length'], errors='coerce')

# %%
# Verifying that the amount of NaN is the same as before
df['emp_length'].isnull().sum()
# Out:
# np.int64(77391)

# %%
# Another check that everything besides the NaN converted correctly:
df['emp_length'].value_counts(dropna=False)
# Out:
# emp_length
# 10.0    435275
# 1.0     193779
# 2.0     119830
# 3.0     106021
# 5.0      82985
# 4.0      79391
# NaN      77391
# 6.0      61856
# 8.0      59912
# 7.0      58915
# 9.0      50180
# Name: count, dtype: int64

# %%
# Create a binary indicator to capture missing employment length, 
# allowing the model to learn from missingness:

df['emp_length_missing'] = df['emp_length'].isnull().astype(int)

# %%
# Checking the column:
df['emp_length_missing'].value_counts()
# Out:
# emp_length_missing
# 0    1248144
# 1      77391
# Name: count, dtype: int64

# %%
# Replace missing employment length values with -1 in the original emp_length column
# to retain observations for modeling :

df['emp_length'] = df['emp_length'].fillna(-1)

# %%
# Making sure there is no more missing values in the column:
df['emp_length'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Checking the new values of the column, there should be 77,391 of -1
df['emp_length'].value_counts(dropna=False)
# Out:
# emp_length
#  10.0    435275
#  1.0     193779
#  2.0     119830
#  3.0     106021
#  5.0      82985
#  4.0      79391
# -1.0      77391
#  6.0      61856
#  8.0      59912
#  7.0      58915
#  9.0      50180
# Name: count, dtype: int64

# %% [markdown]
# ## 4.4 Missing Value Imputation Strategy
#
# To handle the remaining missing values in the dataset, variables are going to be grouped according to their meaning rather than treated individually. This approach ensures that missing data are filled in a way that is consistent with the underlying financial interpretation of each feature.
#
# Event-based variables, such as counts of inquiries, delinquencies, charge-offs, bankruptcies, or tax liens, are imputed with zero because missing values in these cases are interpreted as the absence of the event. Time-based variables that measure the number of months since a financial event are imputed with -1, which is used as a placeholder to indicate that the event has never occurred. Continuous financial variables, such as balances, credit limits, utilization measures, and other numeric account-level characteristics, are imputed using the median to preserve the overall distribution of the data while reducing sensitivity to outliers.
#
# This grouped imputation strategy provides a structured and defensible way to complete the dataset for modeling without relying on a single rule for all variables.

# %%
# Event-based variables: missing values indicate that no event occurred,
# so they are safely imputed with 0

event_cols = [
    'inq_last_6mths',
    'collections_12_mths_ex_med',
    'inq_fi',
    'inq_last_12m',
    'num_tl_30dpd',
    'num_tl_90g_dpd_24m',
    'num_tl_120dpd_2m',
    'chargeoff_within_12_mths',
    'pub_rec_bankruptcies',
    'tax_liens'
]

df[event_cols] = df[event_cols].fillna(0)

# %%
# Checking one of the event-based columns
df['inq_last_6mths'].value_counts()
# Out:
# inq_last_6mths
# 0.0    756815
# 1.0    362042
# 2.0    135611
# 3.0     51396
# 4.0     13787
# 5.0      4874
# 6.0       940
# 7.0        48
# 8.0        22
# Name: count, dtype: int64

# %%
# Time-based variables: missing values indicate that the event has never occurred,
# so they are imputed with -1 to explicitly capture this condition

time_cols = [
    'mths_since_last_delinq',
    'mths_since_rcnt_il',
    'mths_since_recent_bc',
    'mths_since_recent_inq',
    'mths_since_recent_revol_delinq'
]

df[time_cols] = df[time_cols].fillna(-1)

# %%
# Checking one of the time-based variables:
df['mths_since_last_delinq'].value_counts()
# Out:
# mths_since_last_delinq
# -1.0      668041
#  12.0      12589
#  13.0      12541
#  9.0       12518
#  6.0       12433
#            ...
#  143.0         1
#  180.0         1
#  140.0         1
#  159.0         1
#  202.0         1
# Name: count, Length: 164, dtype: int64

# %%
# Continuous financial variables: missing values are imputed using the median
# to preserve the distribution and reduce the influence of outliers

financial_cols = [
    'dti',
    'revol_util',
    'tot_coll_amt',
    'tot_cur_bal',
    'total_bal_il',
    'il_util',
    'total_rev_hi_lim',
    'total_cu_tl',
    'avg_cur_bal',
    'bc_open_to_buy',
    'bc_util',
    'max_bal_bc',
    'all_util',
    'total_bal_ex_mort',
    'total_bc_limit',
    'total_il_high_credit_limit',
    'tot_hi_cred_lim'
]

for col in financial_cols :
    df[col] = df[col].fillna(df[col].median())

# %%
# Account-level count variables: imputed with median to maintain consistency
# while avoiding distortion from extreme values

account_cols = [
    'open_acc_6m',
    'open_act_il',
    'open_il_12m',
    'open_il_24m',
    'open_rv_12m',
    'open_rv_24m',
    'acc_open_past_24mths',
    'num_accts_ever_120_pd',
    'num_actv_bc_tl',
    'num_actv_rev_tl',
    'num_bc_sats',
    'num_bc_tl',
    'num_il_tl',
    'num_op_rev_tl',
    'num_rev_accts',
    'num_rev_tl_bal_gt_0',
    'num_sats',
    'num_tl_op_past_12m',
    'pct_tl_nvr_dlq',
    'percent_bc_gt_75'
]

for col in account_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
# Grouping all of the columns with treated missing values together:

treated_num_cols = event_cols + time_cols + financial_cols + account_cols

# %%
# Checking if there are any left out columns:

left_out_num_cols = [col for col in missing_num_cols if col not in treated_num_cols]
print(left_out_num_cols)
# Out:
# ['mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc']

# %% [markdown]
# Variables that start with mo_sin_ mean months since something:
#
# * *mo_sin_old_il_acct* = months since oldest installment account
# * *mo_sin_old_rev_tl_op* = months since oldest revolving account opened
# * *mo_sin_rcnt_rev_tl_op* = months since most recent revolving account opened
# * *mo_sin_rcnt_tl* = months since most recent trade line opened
#
# The last one in the list *mort_acc* means number of mortgage accounts.
#
# These variables represent account age and credit profile characteristics.
# Missing values do not indicate absence of activity, but rather unavailable or unreported data,so median imputation is going to be used to preserve the overall distribution without introducing bias.

# %%
# Impute remaining account age variables with the median:

account_age_cols = [
    'mo_sin_old_il_acct',
    'mo_sin_old_rev_tl_op',
    'mo_sin_rcnt_rev_tl_op',
    'mo_sin_rcnt_tl'
]

for col in account_age_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
# Quick check if all of the missing values were treated properly:
df[account_age_cols].isnull().sum()
# Out:
# mo_sin_old_il_acct       0
# mo_sin_old_rev_tl_op     0
# mo_sin_rcnt_rev_tl_op    0
# mo_sin_rcnt_tl           0
# dtype: int64

# %%
# Impute mortgage account count with the median
df['mort_acc'] = df['mort_acc'].fillna(df['mort_acc'].median())

# %%
# Quick check:
df['mort_acc'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Checking the overview off the dataset:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1325535 entries, 100 to 2260664
# Data columns (total 86 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   loan_amnt                       1325535 non-null  int64
#  1   funded_amnt                     1325535 non-null  int64
#  2   funded_amnt_inv                 1325535 non-null  float64
#  3   term                            1325535 non-null  object
#  4   int_rate                        1325535 non-null  float64
#  5   installment                     1325535 non-null  float64
#  6   grade                           1325535 non-null  object
#  7   sub_grade                       1325535 non-null  object
#  8   emp_length                      1325535 non-null  float64
#  9   home_ownership                  1325535 non-null  object
#  10  annual_inc                      1325535 non-null  float64
#  11  verification_status             1325535 non-null  object
#  12  issue_d                         1325535 non-null  object
#  13  purpose                         1325535 non-null  object
#  14  addr_state                      1325535 non-null  object
#  15  dti                             1325535 non-null  float64
#  16  delinq_2yrs                     1325535 non-null  float64
#  17  earliest_cr_line                1325535 non-null  object
#  18  inq_last_6mths                  1325535 non-null  float64
#  19  mths_since_last_delinq          1325535 non-null  float64
#  20  open_acc                        1325535 non-null  float64
#  21  pub_rec                         1325535 non-null  float64
#  22  revol_bal                       1325535 non-null  int64
#  23  revol_util                      1325535 non-null  float64
#  24  total_acc                       1325535 non-null  float64
#  25  initial_list_status             1325535 non-null  object
#  26  collections_12_mths_ex_med      1325535 non-null  float64
#  27  application_type                1325535 non-null  object
#  28  acc_now_delinq                  1325535 non-null  float64
#  29  tot_coll_amt                    1325535 non-null  float64
#  30  tot_cur_bal                     1325535 non-null  float64
#  31  open_acc_6m                     1325535 non-null  float64
#  32  open_act_il                     1325535 non-null  float64
#  33  open_il_12m                     1325535 non-null  float64
#  34  open_il_24m                     1325535 non-null  float64
#  35  mths_since_rcnt_il              1325535 non-null  float64
#  36  total_bal_il                    1325535 non-null  float64
#  37  il_util                         1325535 non-null  float64
#  38  open_rv_12m                     1325535 non-null  float64
#  39  open_rv_24m                     1325535 non-null  float64
#  40  max_bal_bc                      1325535 non-null  float64
#  41  all_util                        1325535 non-null  float64
#  42  total_rev_hi_lim                1325535 non-null  float64
#  43  inq_fi                          1325535 non-null  float64
#  44  total_cu_tl                     1325535 non-null  float64
#  45  inq_last_12m                    1325535 non-null  float64
#  46  acc_open_past_24mths            1325535 non-null  float64
#  47  avg_cur_bal                     1325535 non-null  float64
#  48  bc_open_to_buy                  1325535 non-null  float64
#  49  bc_util                         1325535 non-null  float64
#  50  chargeoff_within_12_mths        1325535 non-null  float64
#  51  delinq_amnt                     1325535 non-null  float64
#  52  mo_sin_old_il_acct              1325535 non-null  float64
#  53  mo_sin_old_rev_tl_op            1325535 non-null  float64
#  54  mo_sin_rcnt_rev_tl_op           1325535 non-null  float64
#  55  mo_sin_rcnt_tl                  1325535 non-null  float64
#  56  mort_acc                        1325535 non-null  float64
#  57  mths_since_recent_bc            1325535 non-null  float64
#  58  mths_since_recent_inq           1325535 non-null  float64
#  59  mths_since_recent_revol_delinq  1325535 non-null  float64
#  60  num_accts_ever_120_pd           1325535 non-null  float64
#  61  num_actv_bc_tl                  1325535 non-null  float64
#  62  num_actv_rev_tl                 1325535 non-null  float64
#  63  num_bc_sats                     1325535 non-null  float64
#  64  num_bc_tl                       1325535 non-null  float64
#  65  num_il_tl                       1325535 non-null  float64
#  66  num_op_rev_tl                   1325535 non-null  float64
#  67  num_rev_accts                   1325535 non-null  float64
#  68  num_rev_tl_bal_gt_0             1325535 non-null  float64
#  69  num_sats                        1325535 non-null  float64
#  70  num_tl_120dpd_2m                1325535 non-null  float64
#  71  num_tl_30dpd                    1325535 non-null  float64
#  72  num_tl_90g_dpd_24m              1325535 non-null  float64
#  73  num_tl_op_past_12m              1325535 non-null  float64
#  74  pct_tl_nvr_dlq                  1325535 non-null  float64
#  75  percent_bc_gt_75                1325535 non-null  float64
#  76  pub_rec_bankruptcies            1325535 non-null  float64
#  77  tax_liens                       1325535 non-null  float64
#  78  tot_hi_cred_lim                 1325535 non-null  float64
#  79  total_bal_ex_mort               1325535 non-null  float64
#  80  total_bc_limit                  1325535 non-null  float64
#  81  total_il_high_credit_limit      1325535 non-null  float64
#  82  hardship_flag                   1325535 non-null  object
#  83  disbursement_method             1325535 non-null  object
#  84  default                         1325535 non-null  int64
#  85  emp_length_missing              1325535 non-null  int64
# dtypes: float64(68), int64(5), object(13)
# memory usage: 879.8+ MB

# %% [markdown]
# ## 4.5 Data Type Identification and Transformation
# We now proceed to data type identification and transformation, which is a critical step before modeling. At this stage, the goal is to examine all variables with object data types and determine their appropriate format. Some of these variables may represent numerical values stored as text, date-related information, or true categorical features. By inspecting and converting these variables into their correct data types, we ensure that the dataset is structured properly and suitable for downstream analysis and modeling.

# %%
# Extract all columns with object data type
object_cols = df.select_dtypes(include='object').columns.tolist()

# Print them
object_cols
# Out:
# ['term',
#  'grade',
#  'sub_grade',
#  'home_ownership',
#  'verification_status',
#  'issue_d',
#  'purpose',
#  'addr_state',
#  'earliest_cr_line',
#  'initial_list_status',
#  'application_type',
#  'hardship_flag',
#  'disbursement_method']

# %%
# Taking a look at our "object" columns:
df[object_cols].head(100)
# Out:
#             term grade sub_grade home_ownership verification_status   issue_d  \
# 100    36 months     D        D5       MORTGAGE     Source Verified  Dec-2018
# 152    60 months     C        C4       MORTGAGE            Verified  Dec-2018
# 170    36 months     A        A3       MORTGAGE        Not Verified  Dec-2018
# 186    36 months     B        B3           RENT        Not Verified  Dec-2018
# 215    36 months     E        E5       MORTGAGE            Verified  Dec-2018
# ...          ...   ...       ...            ...                 ...       ...
# 4768   36 months     C        C1           RENT        Not Verified  Dec-2018
# 4833   60 months     C        C5           RENT     Source Verified  Dec-2018
# 4933   36 months     C        C3       MORTGAGE        Not Verified  Dec-2018
# 4949   60 months     C        C4           RENT     Source Verified  Dec-2018
# 4977   36 months     D        D1           RENT        Not Verified  Dec-2018
#
#                  purpose addr_state earliest_cr_line initial_list_status  \
# 100   debt_consolidation         CA         Jan-2012                   w
# 152          credit_card         OH         Jun-2009                   w
# 170          credit_card         WA         Feb-1999                   w
# 186          credit_card         TX         Dec-2003                   w
# 215          credit_card         MA         Oct-1997                   w
# ...                  ...        ...              ...                 ...
# 4768  debt_consolidation         MT         Oct-2009                   w
# 4833  debt_consolidation         MN         Oct-2006                   w
# 4933            vacation         CA         Sep-2002                   w
# 4949      small_business         FL         Dec-2011                   w
# 4977  debt_consolidation         NJ         Sep-2006                   w
#
#      application_type hardship_flag disbursement_method
# 100         Joint App             N                Cash
# 152         Joint App             N                Cash
# 170         Joint App             N                Cash
# 186        Individual             N                Cash
# 215         Joint App             N                Cash
# ...               ...           ...                 ...
# 4768       Individual             N                Cash
# 4833       Individual             N                Cash
# 4933       Individual             N                Cash
# 4949       Individual             N                Cash
# 4977       Individual             N                Cash
#
# [100 rows x 13 columns]

# %%
# Converting term column to numeric:
df['term'] = df['term'].str.extract('(\d+)').astype(int)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_1246/2436650464.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df['term'] = df['term'].str.extract('(\d+)').astype(int)

# %%
# Checking the 'term' column:
df['term'].head()
# Out:
# 100    36
# 152    60
# 170    36
# 186    36
# 215    36
# Name: term, dtype: int64

# %%
# Convert date variables to datetime:

df['issue_d'] = pd.to_datetime(df['issue_d'])
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'])
# Out:
# /tmp/ipykernel_1246/2775916503.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['issue_d'] = pd.to_datetime(df['issue_d'])
# /tmp/ipykernel_1246/2775916503.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'])

# %%
df['issue_d'].head()
# Out:
# 100   2018-12-01
# 152   2018-12-01
# 170   2018-12-01
# 186   2018-12-01
# 215   2018-12-01
# Name: issue_d, dtype: datetime64[ns]

# %%
df['earliest_cr_line'].head()
# Out:
# 100   2012-01-01
# 152   2009-06-01
# 170   1999-02-01
# 186   2003-12-01
# 215   1997-10-01
# Name: earliest_cr_line, dtype: datetime64[ns]

# %%
# Checking "initial_list_status" if theres any value in this column:
df['initial_list_status'].value_counts()
# Out:
# initial_list_status
# w    768231
# f    557304
# Name: count, dtype: int64

# %% [markdown]
# The variable `initial_list_status` indicates how the loan was funded at origination.
# A value of 'w' (whole loan) means the loan was funded by a single investor or institution,
# while 'f' (fractional) means the loan was split across multiple investors. This feature
# may capture differences in loan structure and investor behavior, which could potentially
# influence default risk.
#
# For modeling purposes, the variable is converted into a binary numeric format, where
# 'w' is mapped to 1 and 'f' is mapped to 0, allowing it to be used in machine learning algorithms.

# %%
# Creating a numerical binary variable:
df['initial_list_status'] = df['initial_list_status'].map({'w': 1, 'f': 0})

# %%
# Quick check:
df['initial_list_status'].value_counts()
# Out:
# initial_list_status
# 1    768231
# 0    557304
# Name: count, dtype: int64

# %% [markdown]
# The variables `grade` and `sub_grade` represent borrower credit quality at different levels of detail. The `grade` variable provides a broad classification from A to G, while `sub_grade` offers a finer ranking within each grade.
#
# To prepare these variables for modeling, `grade` is converted into a numeric scale from 1 to 7, and the numeric component of `sub_grade` is extracted to represent the relative position within each grade. Both variables are retained to preserve interpretability while enabling their use in numerical models.

# %%
# Convert grade to numeric scale (A=1, ..., G=7)
df['grade'] = df['grade'].map({
    'A': 1, 'B': 2, 'C': 3, 'D': 4,
    'E': 5, 'F': 6, 'G': 7
})

# %%
# Quick check:
df['grade'].value_counts().sort_index()
# Out:
# grade
# 1    227559
# 2    384916
# 3    377577
# 4    200273
# 5     93800
# 6     32203
# 7      9207
# Name: count, dtype: int64

# %%
# Extract numeric part of sub_grade (A1 → 1, B3 → 3, etc.):

df['sub_grade'] = df['sub_grade'].str.extract('(\d+)').astype(int)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_1246/1333858624.py:3: SyntaxWarning: invalid escape sequence '\d'
#   df['sub_grade'] = df['sub_grade'].str.extract('(\d+)').astype(int)

# %%
# Quick check:
df['sub_grade'].value_counts().sort_index()
# Out:
# sub_grade
# 1    282934
# 2    261962
# 3    256712
# 4    263805
# 5    260122
# Name: count, dtype: int64

# %%
# Creating numerical binary variable for 'hardship_flag':

df['hardship_flag'] = df['hardship_flag'].map({'N': 0, 'Y': 1})

# %%
# Checking the column:
df['hardship_flag'].value_counts().sort_index()
# Out:
# hardship_flag
# 0    1324755
# 1        780
# Name: count, dtype: int64

# %%
# Converting 'application_type' to binary numerical:

df['application_type'] = df['application_type'].map({
    'Individual': 0,
    'Joint App': 1
})

df['application_type'].value_counts()
# Out:
# application_type
# 0    1300110
# 1      25425
# Name: count, dtype: int64

# %%
# Looking at the 'disbursement_method' variable

df['disbursement_method'].value_counts()
# Out:
# disbursement_method
# Cash         1319285
# DirectPay       6250
# Name: count, dtype: int64

# %% [markdown]
# The variable `disbursement_method` indicates how loan funds were distributed to the borrower.
# A value of 'Cash' means the borrower received the funds directly, while 'DirectPay' indicates
# that the funds were sent directly to creditors (e.g., to pay off existing debt). Although the
# variable is highly imbalanced, it is retained as it may capture differences in borrower behavior
# and loan usage that could influence default risk.

# %%
# Converting to binary numerical:

df['disbursement_method'] = df['disbursement_method'].map({
    'Cash': 0,
    'DirectPay': 1
})

df['disbursement_method'].value_counts()
# Out:
# disbursement_method
# 0    1319285
# 1       6250
# Name: count, dtype: int64

# %% [markdown]
# After converting key variables into numeric format, the remaining categorical features are examined individually. Binary variables such as `hardship_flag` and `application_type` are encoded into numeric form. Other categorical variables, including `home_ownership`, `verification_status`, and `purpose`, are inspected to understand their distributions before deciding on appropriate encoding or transformation strategies.

# %%
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    654902
# RENT        527576
# OWN         142585
# ANY            280
# OTHER          144
# NONE            48
# Name: count, dtype: int64

# %%
# Grouping the rare ones under "OTHER":
df['home_ownership'] = df['home_ownership'].replace({
    'ANY': 'OTHER',
    'NONE': 'OTHER'
})

# %%
# Checking the outcome:
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    654902
# RENT        527576
# OWN         142585
# OTHER          472
# Name: count, dtype: int64

# %%
df['verification_status'].value_counts()
# Out:
# verification_status
# Source Verified    512947
# Verified           414654
# Not Verified       397934
# Name: count, dtype: int64

# %%
# Converting verification status to numeric 
# scale reflecting increasing level of income verification:

df['verification_status'] = df['verification_status'].map({
    'Not Verified': 0,
    'Source Verified': 1,
    'Verified': 2
})

# Checking the outcome:
df['verification_status'].value_counts()
# Out:
# verification_status
# 1    512947
# 2    414654
# 0    397934
# Name: count, dtype: int64

# %%
df['purpose'].value_counts()
# Out:
# purpose
# debt_consolidation    770245
# credit_card           289796
# home_improvement       85946
# other                  76611
# major_purchase         28909
# small_business         15365
# medical                15342
# car                    14330
# moving                  9360
# vacation                8907
# house                   7178
# wedding                 2294
# renewable_energy         926
# educational              326
# Name: count, dtype: int64

# %%
# Group detailed loan purposes into broader categories 
# to reduce dimensionality and improve model stability:

df['purpose'] = df['purpose'].replace({
    'credit_card': 'debt',
    'debt_consolidation': 'debt',

    'home_improvement': 'home',
    'house': 'home',

    'major_purchase': 'purchase',
    'car': 'purchase',

    'small_business': 'business',

    'medical': 'personal',
    'vacation': 'personal',
    'moving': 'personal',
    'wedding': 'personal',
    'educational': 'personal',

    'renewable_energy': 'other'
})

# %%
# Checking the outcome of the transformation:
df['purpose'].value_counts()
# Out:
# purpose
# debt        1060041
# home          93124
# other         77537
# purchase      43239
# personal      36229
# business      15365
# Name: count, dtype: int64

# %%
# Making sure the total looks correct:
df['purpose'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1325535 entries, 100 to 2260664
# Series name: purpose
# Non-Null Count    Dtype
# --------------    -----
# 1325535 non-null  object
# dtypes: object(1)
# memory usage: 20.2+ MB

# %%
# Apply one-hot encoding to categorical variables to convert them into binary indicators,
# allowing the model to interpret categorical information without introducing artificial ordering:

df = pd.get_dummies(df, columns=['home_ownership', 'purpose'], drop_first=True)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_length', 'annual_inc',
#        'verification_status', 'issue_d', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'collections_12_mths_ex_med', 'application_type',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq',
#        'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd',
#        'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl',
#        'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0',
#        'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m',
#        'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75',
#        'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim',
#        'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit',
#        'hardship_flag', 'disbursement_method', 'default', 'emp_length_missing',
#        'home_ownership_OTHER', 'home_ownership_OWN', 'home_ownership_RENT',
#        'purpose_debt', 'purpose_home', 'purpose_other', 'purpose_personal',
#        'purpose_purchase'],
#       dtype='object')

# %%
df.head()
# Out:
#      loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 100      30000        30000          30000.0    36     22.35      1151.16
# 152      40000        40000          40000.0    60     16.14       975.71
# 170      20000        20000          20000.0    36      7.56       622.68
# 186       4500         4500           4500.0    36     11.31       147.99
# 215       8425         8425           8425.0    36     27.27       345.18
#
#      grade  sub_grade  emp_length  annual_inc  verification_status    issue_d  \
# 100      4          5         5.0    100000.0                    1 2018-12-01
# 152      3          4         1.0     45000.0                    2 2018-12-01
# 170      1          3        10.0    100000.0                    0 2018-12-01
# 186      2          3        10.0     38500.0                    0 2018-12-01
# 215      5          5         3.0    450000.0                    2 2018-12-01
#
#     addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 100         CA  30.46          0.0       2012-01-01             0.0
# 152         OH  50.53          0.0       2009-06-01             0.0
# 170         WA  18.92          0.0       1999-02-01             0.0
# 186         TX   4.64          0.0       2003-12-01             0.0
# 215         MA  12.37          0.0       1997-10-01             0.0
#
#      mths_since_last_delinq  open_acc  pub_rec  revol_bal  revol_util  \
# 100                    51.0      11.0      1.0      15603        37.0
# 152                    -1.0      18.0      0.0      34971        64.5
# 170                    48.0       9.0      0.0      25416        29.9
# 186                    25.0      12.0      0.0       4472        15.3
# 215                    -1.0      21.0      0.0      36812        65.7
#
#      total_acc  initial_list_status  collections_12_mths_ex_med  \
# 100       19.0                    1                         0.0
# 152       37.0                    1                         0.0
# 170       19.0                    1                         0.0
# 186       25.0                    1                         0.0
# 215       37.0                    1                         0.0
#
#      application_type  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  \
# 100                 1             0.0           0.0     472330.0          1.0
# 152                 1             0.0           0.0     271068.0          2.0
# 170                 1             0.0           0.0     515779.0          1.0
# 186                 0             0.0         306.0      29137.0          2.0
# 215                 1             0.0           0.0     690320.0          0.0
#
#      open_act_il  open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  \
# 100          3.0          2.0          2.0                 2.0       82850.0
# 152          8.0          3.0          4.0                 5.0      126749.0
# 170          2.0          0.0          1.0                13.0       46153.0
# 186          1.0          1.0          1.0                 3.0       24665.0
# 215          6.0          1.0          6.0                12.0      152382.0
#
#      il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  \
# 100     75.0          0.0          1.0      9713.0      60.0
# 152     87.0          1.0          1.0      5874.0      75.0
# 170     71.0          1.0          2.0      9759.0      39.0
# 186    100.0          3.0          7.0      3612.0      54.0
# 215     70.0          1.0          4.0      9744.0      68.0
#
#      total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  \
# 100           42200.0     1.0          1.0           3.0
# 152           54200.0     4.0          2.0           4.0
# 170           85100.0     2.0          2.0           0.0
# 186           29200.0     0.0          3.0           3.0
# 215           56000.0     7.0          0.0           5.0
#
#      acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 100                   4.0      42939.0         15181.0     46.9
# 152                   5.0      15059.0         14930.0     67.3
# 170                   5.0      57309.0         59684.0     29.9
# 186                   8.0       2428.0         10735.0     28.9
# 215                  10.0      34516.0         11632.0     74.6
#
#      chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 100                       0.0          0.0                83.0
# 152                       0.0          0.0               114.0
# 170                       0.0          0.0               171.0
# 186                       0.0          0.0               180.0
# 215                       0.0          0.0               254.0
#
#      mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 100                  73.0                   23.0             2.0       1.0
# 152                  70.0                    2.0             2.0       1.0
# 170                 238.0                    1.0             1.0       5.0
# 186                  69.0                    2.0             2.0       0.0
# 215                  89.0                   12.0            12.0       4.0
#
#      mths_since_recent_bc  mths_since_recent_inq  \
# 100                  23.0                    8.0
# 152                   2.0                    9.0
# 170                   1.0                   13.0
# 186                   2.0                    6.0
# 215                  18.0                    4.0
#
#      mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 100                            -1.0                    0.0             3.0
# 152                            -1.0                    0.0             7.0
# 170                            48.0                    0.0             5.0
# 186                            -1.0                    1.0             3.0
# 215                            -1.0                    0.0             6.0
#
#      num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 100              4.0          3.0        5.0       10.0            6.0
# 152              9.0          7.0        7.0       26.0            9.0
# 170              5.0          5.0        6.0        5.0            5.0
# 186              5.0          5.0        6.0       10.0           11.0
# 215              8.0          8.0       10.0       16.0           13.0
#
#      num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 100            8.0                  4.0      11.0               0.0
# 152           10.0                  9.0      18.0               0.0
# 170            9.0                  5.0       9.0               0.0
# 186           15.0                  5.0      12.0               0.0
# 215           17.0                  8.0      21.0               0.0
#
#      num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 100           0.0                 0.0                 2.0            89.5
# 152           0.0                 0.0                 4.0           100.0
# 170           0.0                 0.0                 1.0            94.7
# 186           0.0                 0.0                 4.0            91.7
# 215           0.0                 0.0                 2.0           100.0
#
#      percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 100              33.3                   1.0        0.0         527120.0
# 152              42.9                   0.0        0.0         344802.0
# 170              20.0                   0.0        0.0         622183.0
# 186               0.0                   0.0        0.0          53795.0
# 215              50.0                   0.0        0.0         768304.0
#
#      total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 100            98453.0         28600.0                    101984.0
# 152           161720.0         45700.0                    167965.0
# 170            71569.0         85100.0                     74833.0
# 186            29137.0         15100.0                     24595.0
# 215           189194.0         45800.0                    189054.0
#
#      hardship_flag  disbursement_method  default  emp_length_missing  \
# 100              0                    0        0                   0
# 152              0                    0        0                   0
# 170              0                    0        0                   0
# 186              0                    0        0                   0
# 215              0                    0        0                   0
#
#      home_ownership_OTHER  home_ownership_OWN  home_ownership_RENT  \
# 100                 False               False                False
# 152                 False               False                False
# 170                 False               False                False
# 186                 False               False                 True
# 215                 False               False                False
#
#      purpose_debt  purpose_home  purpose_other  purpose_personal  \
# 100          True         False          False             False
# 152          True         False          False             False
# 170          True         False          False             False
# 186          True         False          False             False
# 215          True         False          False             False
#
#      purpose_purchase
# 100             False
# 152             False
# 170             False
# 186             False
# 215             False

# %%
# Filtering out all of boolean columns:

bool_cols = df.select_dtypes(include='bool').columns
bool_cols
# Out:
# Index(['home_ownership_OTHER', 'home_ownership_OWN', 'home_ownership_RENT',
#        'purpose_debt', 'purpose_home', 'purpose_other', 'purpose_personal',
#        'purpose_purchase'],
#       dtype='object')

# %%
# Converting them to numerical:

df[bool_cols] = df[bool_cols].astype(int)

# %%
# Checking the outcome:

df[bool_cols].head()
# Out:
#      home_ownership_OTHER  home_ownership_OWN  home_ownership_RENT  \
# 100                     0                   0                    0
# 152                     0                   0                    0
# 170                     0                   0                    0
# 186                     0                   0                    1
# 215                     0                   0                    0
#
#      purpose_debt  purpose_home  purpose_other  purpose_personal  \
# 100             1             0              0                 0
# 152             1             0              0                 0
# 170             1             0              0                 0
# 186             1             0              0                 0
# 215             1             0              0                 0
#
#      purpose_purchase
# 100                 0
# 152                 0
# 170                 0
# 186                 0
# 215                 0

# %%
df.dtypes.value_counts()
# Out:
# float64           68
# int64             21
# datetime64[ns]     2
# object             1
# Name: count, dtype: int64

# %%
df.select_dtypes(include=['object', 'datetime']).columns
# Out:
# Index(['issue_d', 'addr_state', 'earliest_cr_line'], dtype='object')

# %%
# Checking what dates are in our dataset for all of the issued loans:

df['issue_d'].min(), df['issue_d'].max()
# Out:
# (Timestamp('2007-06-01 00:00:00'), Timestamp('2018-12-01 00:00:00'))

# %%
# Checking the dates for credit history:

df['earliest_cr_line'].min(), df['earliest_cr_line'].max()
# Out:
# (Timestamp('1934-04-01 00:00:00'), Timestamp('2015-09-01 00:00:00'))

# %% [markdown]
# The dataset contains loans issued between 2007 and 2018.
# To create time-based features (loan age and credit history length),we define a fixed reference date of January 1, 2019, which is just after the latest loan in the dataset.This avoids using today's date (which would introduce unrealistic future information).
# * We then calculate:
#   - `loan_age_years`: how long since the loan was issued
#   - `credit_history_years`: how long the borrower has had credit history

# %%
# Changing the current day to 01/01/2019 and converting the date columns:

reference_date = pd.to_datetime('2019-01-01')

df['loan_age_years'] = (reference_date - df['issue_d']).dt.days / 365
df['credit_history_years'] = (reference_date - df['earliest_cr_line']).dt.days / 365

# %%
df[['loan_age_years', 'credit_history_years']].describe().round(2)
# Out:
#        loan_age_years  credit_history_years
# count      1325535.00            1325535.00
# mean             3.59                 19.85
# std              1.62                  7.61
# min              0.08                  3.34
# 25%              2.50                 14.59
# 50%              3.42                 18.43
# 75%              4.51                 23.77
# max             11.59                 84.81

# %%
# Making sure the columns look good:

df[['loan_age_years', 'credit_history_years']].head()
# Out:
#      loan_age_years  credit_history_years
# 100        0.084932              7.005479
# 152        0.084932              9.591781
# 170        0.084932             19.928767
# 186        0.084932             15.095890
# 215        0.084932             21.265753

# %%
# Dropping the date columns and the state address, they are no longer needed:

df = df.drop(columns=['issue_d', 'earliest_cr_line', 'addr_state'])

# %%
# Checking the structure of our dataset:
df.shape
# Out:
# (1325535, 91)

# %%
df.head()
# Out:
#      loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 100      30000        30000          30000.0    36     22.35      1151.16
# 152      40000        40000          40000.0    60     16.14       975.71
# 170      20000        20000          20000.0    36      7.56       622.68
# 186       4500         4500           4500.0    36     11.31       147.99
# 215       8425         8425           8425.0    36     27.27       345.18
#
#      grade  sub_grade  emp_length  annual_inc  verification_status    dti  \
# 100      4          5         5.0    100000.0                    1  30.46
# 152      3          4         1.0     45000.0                    2  50.53
# 170      1          3        10.0    100000.0                    0  18.92
# 186      2          3        10.0     38500.0                    0   4.64
# 215      5          5         3.0    450000.0                    2  12.37
#
#      delinq_2yrs  inq_last_6mths  mths_since_last_delinq  open_acc  pub_rec  \
# 100          0.0             0.0                    51.0      11.0      1.0
# 152          0.0             0.0                    -1.0      18.0      0.0
# 170          0.0             0.0                    48.0       9.0      0.0
# 186          0.0             0.0                    25.0      12.0      0.0
# 215          0.0             0.0                    -1.0      21.0      0.0
#
#      revol_bal  revol_util  total_acc  initial_list_status  \
# 100      15603        37.0       19.0                    1
# 152      34971        64.5       37.0                    1
# 170      25416        29.9       19.0                    1
# 186       4472        15.3       25.0                    1
# 215      36812        65.7       37.0                    1
#
#      collections_12_mths_ex_med  application_type  acc_now_delinq  \
# 100                         0.0                 1             0.0
# 152                         0.0                 1             0.0
# 170                         0.0                 1             0.0
# 186                         0.0                 0             0.0
# 215                         0.0                 1             0.0
#
#      tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 100           0.0     472330.0          1.0          3.0          2.0
# 152           0.0     271068.0          2.0          8.0          3.0
# 170           0.0     515779.0          1.0          2.0          0.0
# 186         306.0      29137.0          2.0          1.0          1.0
# 215           0.0     690320.0          0.0          6.0          1.0
#
#      open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 100          2.0                 2.0       82850.0     75.0          0.0
# 152          4.0                 5.0      126749.0     87.0          1.0
# 170          1.0                13.0       46153.0     71.0          1.0
# 186          1.0                 3.0       24665.0    100.0          3.0
# 215          6.0                12.0      152382.0     70.0          1.0
#
#      open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 100          1.0      9713.0      60.0           42200.0     1.0          1.0
# 152          1.0      5874.0      75.0           54200.0     4.0          2.0
# 170          2.0      9759.0      39.0           85100.0     2.0          2.0
# 186          7.0      3612.0      54.0           29200.0     0.0          3.0
# 215          4.0      9744.0      68.0           56000.0     7.0          0.0
#
#      inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 100           3.0                   4.0      42939.0         15181.0     46.9
# 152           4.0                   5.0      15059.0         14930.0     67.3
# 170           0.0                   5.0      57309.0         59684.0     29.9
# 186           3.0                   8.0       2428.0         10735.0     28.9
# 215           5.0                  10.0      34516.0         11632.0     74.6
#
#      chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 100                       0.0          0.0                83.0
# 152                       0.0          0.0               114.0
# 170                       0.0          0.0               171.0
# 186                       0.0          0.0               180.0
# 215                       0.0          0.0               254.0
#
#      mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 100                  73.0                   23.0             2.0       1.0
# 152                  70.0                    2.0             2.0       1.0
# 170                 238.0                    1.0             1.0       5.0
# 186                  69.0                    2.0             2.0       0.0
# 215                  89.0                   12.0            12.0       4.0
#
#      mths_since_recent_bc  mths_since_recent_inq  \
# 100                  23.0                    8.0
# 152                   2.0                    9.0
# 170                   1.0                   13.0
# 186                   2.0                    6.0
# 215                  18.0                    4.0
#
#      mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 100                            -1.0                    0.0             3.0
# 152                            -1.0                    0.0             7.0
# 170                            48.0                    0.0             5.0
# 186                            -1.0                    1.0             3.0
# 215                            -1.0                    0.0             6.0
#
#      num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 100              4.0          3.0        5.0       10.0            6.0
# 152              9.0          7.0        7.0       26.0            9.0
# 170              5.0          5.0        6.0        5.0            5.0
# 186              5.0          5.0        6.0       10.0           11.0
# 215              8.0          8.0       10.0       16.0           13.0
#
#      num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 100            8.0                  4.0      11.0               0.0
# 152           10.0                  9.0      18.0               0.0
# 170            9.0                  5.0       9.0               0.0
# 186           15.0                  5.0      12.0               0.0
# 215           17.0                  8.0      21.0               0.0
#
#      num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 100           0.0                 0.0                 2.0            89.5
# 152           0.0                 0.0                 4.0           100.0
# 170           0.0                 0.0                 1.0            94.7
# 186           0.0                 0.0                 4.0            91.7
# 215           0.0                 0.0                 2.0           100.0
#
#      percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 100              33.3                   1.0        0.0         527120.0
# 152              42.9                   0.0        0.0         344802.0
# 170              20.0                   0.0        0.0         622183.0
# 186               0.0                   0.0        0.0          53795.0
# 215              50.0                   0.0        0.0         768304.0
#
#      total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 100            98453.0         28600.0                    101984.0
# 152           161720.0         45700.0                    167965.0
# 170            71569.0         85100.0                     74833.0
# 186            29137.0         15100.0                     24595.0
# 215           189194.0         45800.0                    189054.0
#
#      hardship_flag  disbursement_method  default  emp_length_missing  \
# 100              0                    0        0                   0
# 152              0                    0        0                   0
# 170              0                    0        0                   0
# 186              0                    0        0                   0
# 215              0                    0        0                   0
#
#      home_ownership_OTHER  home_ownership_OWN  home_ownership_RENT  \
# 100                     0                   0                    0
# 152                     0                   0                    0
# 170                     0                   0                    0
# 186                     0                   0                    1
# 215                     0                   0                    0
#
#      purpose_debt  purpose_home  purpose_other  purpose_personal  \
# 100             1             0              0                 0
# 152             1             0              0                 0
# 170             1             0              0                 0
# 186             1             0              0                 0
# 215             1             0              0                 0
#
#      purpose_purchase  loan_age_years  credit_history_years
# 100                 0        0.084932              7.005479
# 152                 0        0.084932              9.591781
# 170                 0        0.084932             19.928767
# 186                 0        0.084932             15.095890
# 215                 0        0.084932             21.265753

# %%
df.dtypes.value_counts()
# Out:
# float64    70
# int64      21
# Name: count, dtype: int64

# %% [markdown]
# All of the columns are converted to numerical

# %%
# Making sure there are no more missing values
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 5. Final Dataset Preparation for Modeling
# In this step, the dataset is finalized for modeling by removing redundant variables, ensuring all features are numerical, and separating the target variable from the predictors. This prepares the data for training machine learning models.

# %% [markdown]
# Our variable `default` represents whether a borrower defaulted (target),while all other variables are used as predictors. In order to prevent data leakage during model training we need to remove default from our dataset

# %%
# Confirming that our target is still there:

'default' in df.columns
# Out:
# True

# %%
df['default'].value_counts()
# Out:
# default
# 0    1041952
# 1     283583
# Name: count, dtype: int64

# %%
# Separate the dataset into features (X) and target variable (y)
# 'default' is the outcome we want to predict, so it is removed from X
# to prevent data leakage and used as the target variable y
X = df.drop('default', axis=1)
y = df['default']

# %% [markdown]
# At this stage, the dataset is fully cleaned and transformed, making it suitable for modeling. The target variable, `default`, is separated from the predictor variables to avoid data leakage. All remaining features are retained as input variables.
#
# The feature matrix X contains all predictor variables, while the target vector y represents the loan default outcome (1 = default, 0 = non-default). This separation ensures that the model is trained only on information that would be available at the time of prediction.

# %% [markdown]
# ## 6. Train-Test Split
#
# To evaluate model performance, the dataset is divided into training and testing subsets. The training set is used to build and tune the model, while the testing set remains unseen during training and is used to assess generalization performance. This separation ensures that model evaluation reflects how well it can perform on new, unseen data and helps mitigate the risk of overfitting.
